# %% [markdown]
# # Credit Card Fraud Dataset

# %%
#import import_ipynb 
import Template_2 as t
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=t.load_data('csv')
# Out:
# Enter path of filecreditcard.csv

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
t.missing_details(df)
# Out:
#         Missing value, %  Missing value count  N unique value
# Time                 0.0                    0          124592
# V1                   0.0                    0          275663
# V2                   0.0                    0          275663
# V3                   0.0                    0          275663
# V4                   0.0                    0          275663
# V5                   0.0                    0          275663
# V6                   0.0                    0          275663
# V7                   0.0                    0          275663
# V8                   0.0                    0          275663
# V9                   0.0                    0          275663
# V10                  0.0                    0          275663
# V11                  0.0                    0          275663
# V12                  0.0                    0          275663
# V13                  0.0                    0          275663
# ...

# %%
t.remove_cols(df,'Time')

# %% [markdown]
# The features V1 to V28 are principal components of the original dataset.

# %%
t.numerical_analysis(df,'Amount')
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64
# Skew is 16.97763503663315
# Kurtosis is 845.0777883188754
# Cannot be considered normally distributed on the basis of skewness and kurtosis
#
#
# Shapiro Wilk Test for Normality
# E:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1660: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# stat=0.310,p=0.000
#
# Not Normally distributed according to shapiro test
#
#
# Anderson Test for Normality
# stat=54953.603
# Probably Not Normally distributed 0.576 critical value at 15.0 level of significance
# Probably Not Normally distributed 0.656 critical value at 10.0 level of significance
# Probably Not Normally distributed 0.787 critical value at 5.0 level of significance
# ...

# %%
t.categorical_analysis(df,'Class')
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Extreme class imbalance exists in this dataset.

# %%
import seaborn as sns
sns.pairplot(df[['Amount','Class']])

# %% [markdown]
# Plots suggest frauds occur when the amount of transaction is small.

# %%
t.anova(df,'Amount','Class')
# Out:
#                 df        sum_sq        mean_sq         F    PR(>F)
# Class          1.0  5.651107e+05  565110.729179  9.033345  0.002651
# Residual  284805.0  1.781692e+10   62558.304503       NaN       NaN

# %% [markdown]
# ANOVA test validates our findings. It suggests that the amount is a significant factor in determining fraud.

# %% [markdown]
# ## Clustering

# %%
df2=df.copy()

# %%
df2
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
ss=MinMaxScaler()
ss=ss.fit(df2)
df2=ss.transform(df2)

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %%
df2=pd.DataFrame(df2,columns=['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'])

# %%
df2
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0       0.935192  0.766490  0.881365  0.313023  0.763439  0.267669  0.266815
# 1       0.978542  0.770067  0.840298  0.271796  0.766120  0.262192  0.264875
# 2       0.935217  0.753118  0.868141  0.268766  0.762329  0.281122  0.270177
# 3       0.941878  0.765304  0.868484  0.213661  0.765647  0.275559  0.266803
# 4       0.938617  0.776520  0.864251  0.269796  0.762975  0.263984  0.268968
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.756448  0.873531  0.666991  0.160317  0.729603  0.236810  0.235393
# 284803  0.945845  0.766677  0.872678  0.219189  0.771561  0.273661  0.265504
# 284804  0.990905  0.764080  0.781102  0.227202  0.783425  0.293496  0.263547
# 284805  0.954209  0.772856  0.849587  0.282508  0.763172  0.269291  0.261175
# 284806  0.949232  0.765256  0.849601  0.229488  0.765632  0.256488  0.274963
#
# ...

# %% [markdown]
# ### Kmeans

# %%
t.elbow_plot_kmeans(df2,yellow=True)
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# E:\ProgramData\Anaconda3\lib\site-packages\yellowbrick\utils\kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# E:\ProgramData\Anaconda3\lib\site-packages\yellowbrick\cluster\elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
t.elbow_plot_kmeans(df2,yellow=False)

# %% [markdown]
# K means elbow plot suggests that clustering will not be suitable for this dataset as a distinct number of clusters have not been identified.

# %% [markdown]
# ## MACHINE LEARNING

# %%
df3=t.deep_copy(df)

# %%
df3
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
t.corr_heatmap(df3)

# %%
df3.corr()
# Out:
#                   V1            V2            V3            V4            V5  \
# V1      1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17  6.391162e-17
# V2      4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16 -2.039868e-16
# V3     -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16 -1.436514e-15
# V4      1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00 -1.940929e-15
# V5      6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15  1.000000e+00
# V6      2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16  7.926364e-16
# V7      1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16 -4.209851e-16
# V8     -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16  7.589187e-16
# V9      2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16  4.205206e-16
# V10     7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16 -6.601716e-16
# V11     2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16  7.342759e-16
# ...

# %% [markdown]
# There are no highly correlated features in the dataset. Understandably PCA generates components which are un related to each other

# %% [markdown]
# Obtaining list of important features using random forest feature selector.

# %%
x=df3.drop(['Class'], axis=1)
y=df3['Class']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
for i in x.columns:
    x[i] = ss.fit_transform(x[[i]])

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest , ytrain, ytest =train_test_split(x,y,test_size=0.20,random_state=42 )

# %%
def RFfeatureimportance(df, xtrain, xtest, ytrain, ytest, trees=35, random=None, regression=False):
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.ensemble import RandomForestRegressor
    if regression:
        clf  = RandomForestRegressor(n_estimators=trees, random_state=random)
    else:
        clf  = RandomForestClassifier(n_estimators=trees, random_state=random)
    clf.fit(xtrain,ytrain)
    #validationmetrics(clf,testX,testY)
    res = pd.Series(clf.feature_importances_, index=xtrain.columns.values).sort_values(ascending=False)*100
    print(res)
    return res

# %%
RFfeatureimportance(df3, xtrain, xtest, ytrain, ytest, trees=35, random=None, regression=False)
# Out:
# V17       16.061181
# V14       14.444364
# V12       12.708378
# V11        9.101946
# V10        6.373442
# V16        4.924234
# V7         4.095620
# V9         3.821215
# V4         2.971341
# V18        1.771752
# V6         1.745629
# V21        1.662504
# V1         1.625321
# V26        1.565287
# V20        1.401798
# V27        1.374193
# V19        1.374044
# V28        1.358571
# V2         1.353773
# V8         1.259303
# V3         1.256942
# V5         1.219687
# Amount     1.183006
# V15        1.059247
# V13        1.052147
# V22        0.978910
# V25        0.794145
# V24        0.761738
# V23        0.700281
# dtype: float64
# V17       16.061181
# V14       14.444364
# V12       12.708378
# V11        9.101946
# V10        6.373442
# V16        4.924234
# V7         4.095620
# V9         3.821215
# V4         2.971341
# V18        1.771752
# V6         1.745629
# V21        1.662504
# V1         1.625321
# V26        1.565287
# V20        1.401798
# ...

# %%
df3.to_csv('cleaned_encoded2.csv',index=False)

# %% [markdown]
# Since there exists a class imbalance in the target variable, f1 score and recall score will be used to judge performance.

# %% [markdown]
# ### ML Algorithms without Cross Validation

# %%
df3=pd.read_csv('cleaned_encoded2.csv')

# %%
df3
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
t.fit_model(df3,'Class',classification=True,min_max=False,svm_type = "Linear")
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ---------Logistic Regression------------
# Accuracy  (%):
#  99.91222218320986
# Precision:
#  86.36363636363636
# Recall (%):
#  58.16326530612245
# f1 score (%):
#  69.51219512195121
# logistic loss :
#  0.030317510201932213
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.58      0.70        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.79      0.85     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ...

# %% [markdown]
# ### ML Algorithms with Random Forest Feature selection

# %%
t.fit_model_RFS(df3,'Class',threshold=5,classification=True,min_max=False,svm_type='Linear')
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# V17       16.647648
# V12       14.605269
# V14       14.594389
# V11        7.759257
# V10        7.558571
# V16        4.413669
# V9         3.940086
# V18        2.812468
# V7         2.542144
# V4         2.032856
# V26        1.899388
# V21        1.895700
# V3         1.389091
# V1         1.318847
# V8         1.312289
# V6         1.299715
# V19        1.281987
# V5         1.275375
# V15        1.257592
# V28        1.243067
# V2         1.213761
# V25        1.108138
# V27        1.053698
# V20        1.031156
# V24        1.023900
# Amount     0.967009
# ...

# %% [markdown]
# ### ML Algorithms with Cross Validation

# %%
t.fit_model_CV(df3,'Class',split=10,classification=True,min_max=False,svm_type='Linear')
# Out:
# _____Cross Validation_____
# ---------Logistic Regression------------
# Mean accuracy  (%):
#  99.9262659625293
# Mean AUC  (%):
#  97.43895493386546
# Mean Precision:
#  88.10739260739261
# Mean Recall (%):
#  66.95238095238093
# Mean f1 score (%):
#  75.3307102858827
# ---------Random Forest------------
# Mean accuracy  (%):
#  99.94382186836378
# Mean AUC  (%):
#  93.71900326506791
# Mean Precision:
#  89.39721389721392
# Mean Recall (%):
#  74.38095238095237
# Mean f1 score (%):
#  79.52783359679911
# ---------xgboost------------
# Mean accuracy  (%):
#  99.94499214337841
# Mean AUC  (%):
#  97.0934141022943
# Mean Precision:
#  91.07625707625708
# Mean Recall (%):
#  75.71428571428571
# Mean f1 score (%):
#  82.52165663200147
# ---------SVM------------
# Mean accuracy  (%):
#  99.93797021934986
# Mean AUC  (%):
#  96.81311545753145
# Mean Precision:
#  92.3901098901099
# Mean Recall (%):
#  71.04761904761905
# Mean f1 score (%):
#  78.64402200609098
# ______Test_______
# ...

# %% [markdown]
# ### ML Algorithms with Cross Validation and Random Forest Feature Selection

# %%
t.fit_model_CV_FS(df3,'Class',split=10,classification=True,threshold=5,min_max=False,svm_type='Linear')
# Out:
# V17       20.943519
# V14       11.446640
# V12       10.974340
# V11        8.366968
# V10        7.145644
# V16        5.437478
# V18        3.437907
# V4         3.152367
# V7         2.700227
# V21        2.204812
# V26        1.860617
# V9         1.699181
# V1         1.691306
# V6         1.640574
# V5         1.500402
# V8         1.424104
# V19        1.385519
# V27        1.340306
# V20        1.321588
# V13        1.302163
# V3         1.129125
# V15        1.114229
# V22        1.069731
# Amount     1.053373
# V24        1.021095
# V2         1.004278
# V25        0.983944
# V28        0.972305
# V23        0.676260
# dtype: float64
# Selected Features =['V17', 'V14', 'V12', 'V11', 'V10', 'V16']
# _____Cross Validation_____
# ---------Logistic Regression------------
# Mean accuracy  (%):
#  99.92392472764807
# Mean AUC  (%):
#  94.57678100056268
# Mean Precision:
#  91.07264957264955
# Mean Recall (%):
#  62.85714285714287
# Mean f1 score (%):
#  73.84316247359727
# ...

# %% [markdown]
# ### ML algorithms with oversampling without Random Forest Feature Selection and Cross Validation

# %%
t.fit_model_os(df3,'Class',ratio=0.5,classification=True,min_max=False,svm_type='Linear')
# Out:
# ---------Logistic Regression------------
# Accuracy  (%):
#  98.88346617042941
# Precision:
#  12.430167597765362
# Recall (%):
#  90.81632653061224
# f1 score (%):
#  21.867321867321866
# logistic loss :
#  0.38564592420827887
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.12      0.91      0.22        98
#
#     accuracy                           0.99     56962
#    macro avg       0.56      0.95      0.61     56962
# weighted avg       1.00      0.99      0.99     56962
#
# AUC  (%):
#  98.07465790199029
# Best Threshold=0.409479, G-Mean=0.951
# ---------Random Forest------------
# Accuracy  (%):
#  99.96488887328394
# Precision:
#  98.75
# Recall (%):
#  80.61224489795919
# f1 score (%):
#  88.76404494382022
# logistic loss :
#  0.012126967583576781
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
# ...

# %% [markdown]
# ### ML algorithms with undersampling without Random Forest Feature Selection and Cross Validation

# %%
t.fit_model_us(df3,'Class',ratio=0.5,classification=True,min_max=False,svm_type='Linear')
# Out:
# ---------Logistic Regression------------
# Accuracy  (%):
#  97.92317685474526
# Precision:
#  7.04671417260491
# Recall (%):
#  90.81632653061224
# f1 score (%):
#  13.07861866274798
# logistic loss :
#  0.7173257821453325
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.07      0.91      0.13        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.94      0.56     56962
# weighted avg       1.00      0.98      0.99     56962
#
# AUC  (%):
#  98.06009576734465
# Best Threshold=0.737018, G-Mean=0.948
# ---------Random Forest------------
# Accuracy  (%):
#  98.3778659457182
# Precision:
#  8.78243512974052
# Recall (%):
#  89.79591836734694
# f1 score (%):
#  16.000000000000004
# logistic loss :
#  0.5602780840024704
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
# ...

# %% [markdown]
# ### ML algorithms with oversampling and Random Forest Feature Selection

# %%
t.fit_model_RFS_os(df3,'Class',ratio=0.5,threshold=5,classification=True,min_max=False,svm_type='Linear')
# Out:
# V17       21.072489
# V14       12.364622
# V16        9.679163
# V10        6.394298
# V11        6.208094
# V12        6.031278
# V9         5.520655
# V7         2.860466
# V4         2.815512
# V21        2.497964
# V18        2.328812
# V26        2.027735
# V3         1.728372
# V6         1.620285
# V27        1.548196
# V2         1.543618
# V1         1.398897
# Amount     1.382032
# V5         1.293508
# V20        1.202737
# V13        1.153914
# V28        1.052799
# V19        1.045844
# V15        1.013344
# V22        1.006755
# V24        0.923860
# V25        0.821223
# V8         0.792315
# V23        0.671216
# dtype: float64
# Selected Features =['V17', 'V14', 'V16', 'V10', 'V11', 'V12', 'V9']
# ---------Logistic Regression------------
# Accuracy  (%):
#  99.01513289561463
# Precision:
#  13.428120063191153
# Recall (%):
#  86.73469387755102
# f1 score (%):
#  23.25581395348837
# logistic loss :
#  0.34016873945677284
# ...

# %% [markdown]
# ### ML algorithms with undersampling and Random Forest Feature Selection

# %%
t.fit_model_RFS_us(df3,'Class',ratio=0.5,threshold=5,classification=True,min_max=False,svm_type='Linear')
# Out:
# V17       15.852024
# V14       11.226574
# V11       10.643484
# V12       10.503580
# V16        9.389052
# V10        6.703404
# V9         3.805522
# V18        3.554099
# V26        2.518311
# V4         2.203838
# V7         2.097297
# V6         1.707698
# V1         1.672386
# V21        1.546329
# V8         1.517676
# V3         1.511889
# Amount     1.372626
# V19        1.176592
# V22        1.134232
# V24        1.107009
# V13        1.050982
# V2         1.024371
# V15        1.019649
# V27        1.007052
# V20        1.006986
# V25        1.001393
# V23        0.907842
# V5         0.890072
# V28        0.848030
# dtype: float64
# Selected Features =['V17', 'V14', 'V11', 'V12', 'V16', 'V10']
# ---------Logistic Regression------------
# Accuracy  (%):
#  98.95719953653312
# Precision:
#  12.874251497005988
# Recall (%):
#  87.75510204081633
# f1 score (%):
#  22.454308093994772
# logistic loss :
#  0.3601786900790241
# ...

# %% [markdown]
# ### ML algorithms with oversampling and Cross Validation

# %%
t.fit_model_CV_OS(df3,'Class',ratio=0.5,split=10,classification=True,min_max=False,svm_type='Linear')
# Out:
# _____Cross Validation_____
# ---------Logistic Regression------------
# Mean accuracy  (%):
#  95.81932995855695
# Mean AUC  (%):
#  98.73864718425956
# Mean Precision:
#  97.46656463077889
# Mean Recall (%):
#  89.8420373149601
# Mean f1 score (%):
#  93.49846480542521
# ---------Random Forest------------
# Mean accuracy  (%):
#  99.99120693022299
# Mean AUC  (%):
#  99.99779746462652
# Mean Precision:
#  99.97081995765718
# Mean Recall (%):
#  100.0
# Mean f1 score (%):
#  99.98540572077088
# ---------xgboost------------
# Mean accuracy  (%):
#  99.9785059885195
# Mean AUC  (%):
#  99.99826976858755
# Mean Precision:
#  99.93583452598595
# Mean Recall (%):
#  100.0
# Mean f1 score (%):
#  99.96789982302063
# ---------SVM------------
# Mean accuracy  (%):
#  95.63271960052484
# Mean AUC  (%):
#  98.68541507721356
# Mean Precision:
#  97.90661529748631
# Mean Recall (%):
#  89.00990176683266
# Mean f1 score (%):
#  93.22131451313655
# ______Test_______
# ...

# %% [markdown]
# ### ML algorithms with undersampling and Cross Validation¶

# %%
t.fit_model_CV_US(df3,'Class',ratio=0.5,split=10,classification=True,min_max=False,svm_type='Linear')
# Out:
# _____Cross Validation_____
# ---------Logistic Regression------------
# Mean accuracy  (%):
#  94.36507936507937
# Mean AUC  (%):
#  95.93666666666667
# Mean Precision:
#  93.51515151515152
# Mean Recall (%):
#  88.0909090909091
# Mean f1 score (%):
#  90.42424242424244
# ---------Random Forest------------
# Mean accuracy  (%):
#  94.0952380952381
# Mean AUC  (%):
#  97.69121212121213
# Mean Precision:
#  95.88888888888889
# Mean Recall (%):
#  85.27272727272728
# Mean f1 score (%):
#  90.19047619047619
# ---------xgboost------------
# Mean accuracy  (%):
#  92.96031746031746
# Mean AUC  (%):
#  96.97878787878787
# Mean Precision:
#  91.9028749028749
# Mean Recall (%):
#  85.27272727272728
# Mean f1 score (%):
#  88.05985319028797
# ---------SVM------------
# Mean accuracy  (%):
#  93.53968253968254
# Mean AUC  (%):
#  95.76181818181817
# Mean Precision:
#  93.34343434343435
# Mean Recall (%):
#  86.27272727272727
# Mean f1 score (%):
#  88.93939393939394
# ______Test_______
# ...

# %% [markdown]
# ### ML algorithms with oversampling, Random Forest Feature Selection and Cross Validation

# %%
t.fit_model_CV_FS_OS(df3,'Class',ratio=0.5,split=10,classification=True,threshold=5,min_max=False,svm_type='Linear')
# Out:
# V17       16.031380
# V14       13.334563
# V12       12.732450
# V10        8.544187
# V11        7.093741
# V18        4.261405
# V16        3.763262
# V9         3.286721
# V7         3.228752
# V4         2.252433
# V6         2.033370
# V3         1.823272
# V26        1.818091
# V21        1.795373
# V2         1.633727
# V1         1.430029
# V15        1.404391
# V5         1.403701
# V27        1.360093
# V8         1.309127
# V19        1.282495
# V20        1.260878
# Amount     1.173577
# V22        1.170913
# V24        1.042186
# V28        0.944807
# V13        0.923981
# V25        0.886312
# V23        0.774783
# dtype: float64
# Selected Features =['V17', 'V14', 'V12', 'V10', 'V11']
# _____Cross Validation_____
# ---------Logistic Regression------------
# Mean accuracy  (%):
#  94.73092610866215
# Mean AUC  (%):
#  96.15124301449247
# Mean Precision:
#  97.75101095808874
# Mean Recall (%):
#  86.23899652090866
# Mean f1 score (%):
#  91.63373138266049
# ...

# %% [markdown]
# ### ML algorithms with undersampling, Random Forest Feature Selection and Cross Validation

# %%
t.fit_model_CV_FS_US(df3,'Class',ratio=0.5,split=10,classification=True,threshold=5,min_max=False,svm_type='Linear')
# Out:
# V12       18.908698
# V17       14.630704
# V14       10.187739
# V10        8.054567
# V11        7.644501
# V16        5.909545
# V9         3.961119
# V4         2.786767
# V7         2.307366
# V26        1.899134
# V27        1.712534
# V3         1.650630
# V21        1.565631
# V20        1.500667
# V8         1.375199
# V6         1.333443
# V28        1.318543
# V19        1.316878
# Amount     1.294548
# V1         1.242745
# V15        1.221669
# V24        1.137140
# V18        1.134349
# V2         1.133097
# V13        1.093642
# V5         1.007060
# V25        0.960442
# V22        0.959212
# V23        0.752431
# dtype: float64
# Selected Features =['V12', 'V17', 'V14', 'V10', 'V11', 'V16']
# _____Cross Validation_____
# ---------Logistic Regression------------
# Mean accuracy  (%):
#  94.65079365079364
# Mean AUC  (%):
#  94.29393939393937
# Mean Precision:
#  98.09090909090908
# Mean Recall (%):
#  84.36363636363635
# Mean f1 score (%):
#  90.39667350193668
# ...

# %% [markdown]
# Best results have been achieved with XGBoost algorithm with oversampling. LDA cannot be performed on this dataset because it has already been dimensionally reduced using PCA.

# %% [markdown]
# ## MCMC

# %%
df4=pd.read_csv('/content/drive/MyDrive/ML2/Untitled Folder/cleaned_encoded2.csv')

# %%
df4
# Out:
#                V1         V2        V3  ...       V28  Amount  Class
# 0       -1.359807  -0.072781  2.536347  ... -0.021053  149.62      0
# 1        1.191857   0.266151  0.166480  ...  0.014724    2.69      0
# 2       -1.358354  -1.340163  1.773209  ... -0.059752  378.66      0
# 3       -0.966272  -0.185226  1.792993  ...  0.061458  123.50      0
# 4       -1.158233   0.877737  1.548718  ...  0.215153   69.99      0
# ...           ...        ...       ...  ...       ...     ...    ...
# 284802 -11.881118  10.071785 -9.834783  ...  0.823731    0.77      0
# 284803  -0.732789  -0.055080  2.035030  ... -0.053527   24.79      0
# 284804   1.919565  -0.301254 -3.249640  ... -0.026561   67.88      0
# 284805  -0.240440   0.530483  0.702510  ...  0.104533   10.00      0
# 284806  -0.533413  -0.189733  0.703337  ...  0.013649  217.00      0
#
# [284807 rows x 30 columns]

# %%
import pymc3 as pm
import arviz as az

# %% [markdown]
# Selecting only Amount as the input variable for bayesian analysis because all other features are principal components.

# %%
y_0=pd.Categorical(df4['Class']).codes

# %%
x_n = 'Amount'
x_0 = df4[x_n].values
x_c = x_0 - x_0.mean()#Centring around mean

# %%
from sklearn.model_selection import train_test_split
x_c_train, x_c_test, y_0_train, y_0_test=train_test_split(x_c,y_0,test_size=0.2,stratify=y_0)

# %%
with pm.Model() as model_0:
  x_c_train = pm.Data('x', x_c_train)
  y_0_train = pm.Data('y', y_0_train)
  α = pm.Normal('α', mu=0, sd=10)
  β = pm.Normal('β', mu=0, sd=10)
  μ = α + pm.math.dot(x_c_train, β)
  θ = pm.Deterministic('θ', pm.math.sigmoid(μ))
  bd = pm.Deterministic('bd', -α/β)
  yl = pm.Bernoulli('yl', p=θ, observed=y_0_train)
  trace_0 = pm.sample(200)#Selecting only 200 samples because of insufficient RAM
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   # Remove the CWD from sys.path while we load stuff.
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [β, α]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
# ...

# %%
az.summary(trace_0,var_names=['β','α','bd'])
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#           mean           sd      hdi_3%  ...  ess_bulk  ess_tail  r_hat
# β        0.000        0.000      -0.000  ...     299.0     224.0   1.00
# α       -6.360        0.051      -6.435  ...     399.0     308.0   1.01
# bd -119667.275  2587701.556 -286673.257  ...     443.0     333.0   1.00
#
# [3 rows x 9 columns]

# %%
#prior_predictive = pm.sample_prior_predictive(model=model_0)

#posterior_predictive = pm.sample_posterior_predictive(model=model_0,trace=trace_0)
#dataset = az.from_pymc3(trace=trace_0, posterior_predictive=posterior_predictive,prior=prior_predictive)
#az.plot_ppc(dataset);
t.plot_ppc(model_0,trace_0)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:15<00:00]
#     </div>
# Got error No model on context stack. trying to find log_likelihood in translation.
# ...

# %% [markdown]
# Posterior predictive check is inconclusive because the number of samples selected is very small. This dataset exceeds computational capability available.

# %% [markdown]
# Generating predictions for test set.

# %%
t.pred(model_0,trace_0,x_c_test,y_0_test)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:21<00:00]
#     </div>
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.00      0.00      0.00        98
#
#     accuracy                           1.00     56962
#    macro avg       0.50      0.50      0.50     56962
# ...

# %% [markdown]
# #### This dataset exceeds computational capabilities available to perform Bayesian analysis.
